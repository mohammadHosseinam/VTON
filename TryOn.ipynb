# %%
import tensorflow as tf
import os
from PIL import Image, ImageDraw
import numpy as np
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def download_dataset():
    drive_dir = "/content/drive/MyDrive/viton-plus"
    os.makedirs(drive_dir)
    # !kaggle datasets download mohammadalijalili/viton-plus -p {drive_dir}
    # !unzip /content/drive/MyDrive/viton-plus/viton-plus.zip -d {drive_dir}/viton-plus

# %%
 drive_dir = "/content/drive/MyDrive/viton-plus"

 if not os.path.exists(drive_dir):
    download_dataset()
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012689_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012690_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012692_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012693_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012695_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012696_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012697_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012698_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012699_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012700_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012701_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012703_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012704_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012705_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012706_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012707_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012709_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012710_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012714_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012715_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012717_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012718_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012721_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012722_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012724_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012726_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012727_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012728_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012729_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012730_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012732_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012733_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012735_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012736_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012737_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012738_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012739_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012740_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012742_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012744_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012745_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012747_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012748_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012749_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012751_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012753_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012755_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012756_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012757_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012758_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012760_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012761_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012762_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012764_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012765_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012766_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012767_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012768_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012769_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012772_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012774_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012775_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012776_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012777_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012782_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012783_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012784_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012787_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012788_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012789_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012791_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012792_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012793_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012794_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012796_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012797_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012798_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012799_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012800_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012801_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012802_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012804_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012805_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012806_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012807_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012808_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012809_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012810_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012812_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012813_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012814_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012818_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012819_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012820_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012821_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012823_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012824_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012825_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012826_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012827_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012828_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012829_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012831_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012832_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012833_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012834_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012835_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012836_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012837_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012840_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012841_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012844_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012845_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012846_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012847_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012848_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012850_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012852_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012853_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012854_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012856_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012858_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012859_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012861_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012862_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012863_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012864_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012865_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012866_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012867_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012870_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012871_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012874_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012875_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012876_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012877_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012878_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012881_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012883_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012884_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012885_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012886_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012887_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012888_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012890_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012892_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012893_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012894_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012895_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012896_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012897_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012900_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012901_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012902_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012903_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012904_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012905_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012906_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012908_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012909_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012911_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012912_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012914_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012915_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012916_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012918_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012919_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012920_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012922_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012923_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012924_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012925_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012927_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012928_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012929_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012930_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012931_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012932_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012933_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012935_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012936_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012937_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012938_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012940_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012941_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012943_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012945_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012946_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012948_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012949_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012950_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012951_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012952_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012954_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012955_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012956_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012957_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012958_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012959_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012961_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012965_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012966_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012967_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012970_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012971_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012972_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012974_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012976_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012977_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012978_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012979_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012981_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012983_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012985_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012988_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012989_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012990_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012991_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012992_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012993_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012994_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/012998_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013000_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013001_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013002_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013004_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013005_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013006_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013008_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013009_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013010_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013013_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013016_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013017_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013018_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013020_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013021_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013022_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013023_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013024_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013025_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013027_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013029_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013030_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013031_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013032_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013033_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013034_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013035_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013037_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013041_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013042_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013043_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013044_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013045_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013046_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013050_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013053_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013055_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013056_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013057_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013058_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013059_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013061_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013062_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013063_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013064_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013065_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013066_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013067_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013069_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013070_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013071_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013072_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013073_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013074_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013075_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013077_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013078_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013079_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013080_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013081_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013082_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013083_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013086_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013087_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013088_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013089_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013091_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013095_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013096_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013098_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013099_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013101_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013102_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013103_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013104_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013105_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013108_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013110_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013111_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013112_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013114_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013115_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013116_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013118_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013119_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013121_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013122_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013123_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013124_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013126_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013128_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013129_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013130_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013131_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013136_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013137_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013138_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013140_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013141_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013142_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013143_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013144_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013145_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013146_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013148_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013149_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013150_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013151_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013152_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013153_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013154_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013156_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013159_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013160_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013161_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013162_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013163_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013164_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013166_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013167_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013168_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013169_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013170_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013171_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013172_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013174_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013175_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013176_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013177_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013178_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013179_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013180_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013182_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013183_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013184_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013185_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013186_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013187_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013188_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013191_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013192_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013193_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013194_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013196_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013197_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013198_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013200_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013205_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013206_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013207_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013208_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013209_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013213_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013215_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013216_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013217_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013218_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013219_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013221_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013222_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013225_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013226_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013227_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013228_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013229_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013230_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013232_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013234_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013236_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013237_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013240_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013242_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013243_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013244_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013246_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013247_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013248_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013251_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013252_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013253_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013254_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013257_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013258_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013259_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013260_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013261_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013262_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013264_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013266_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013267_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013268_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013269_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013270_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013271_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013272_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013274_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013275_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013276_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013279_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013280_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013281_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013282_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013286_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013287_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013288_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013289_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013291_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013293_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013295_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013300_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013303_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013304_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013305_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013306_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013307_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013308_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013311_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013312_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013313_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013314_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013315_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013316_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013318_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013320_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013321_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013322_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013323_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013324_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013325_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013326_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013328_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013329_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013330_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013332_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013335_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013336_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013337_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013339_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013341_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013342_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013346_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013350_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013353_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013354_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013356_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013357_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013358_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013359_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013360_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013361_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013362_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013366_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013367_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013369_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013370_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013371_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013372_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013373_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013375_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013376_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013377_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013378_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013379_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013380_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013381_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013383_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013384_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013385_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013387_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013388_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013389_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013390_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013392_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013394_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013395_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013396_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013397_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013398_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013399_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013401_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013402_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/013403_0_keypoints.json
# ...
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019374_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019375_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019377_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019378_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019379_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019380_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019381_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019382_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019383_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019385_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019386_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019388_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019389_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019390_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019391_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019392_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019395_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019396_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019397_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019398_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019399_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019400_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019401_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019403_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019405_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019406_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019407_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019408_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019409_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019410_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019412_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019413_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019414_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019415_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019416_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019417_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019418_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019421_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019422_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019423_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019425_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019426_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019427_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019428_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019430_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019431_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019432_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019434_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019435_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019436_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019437_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019439_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019440_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019441_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019442_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019443_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019444_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019445_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019447_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019448_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019449_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019450_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019451_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019452_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019453_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019455_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019456_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019459_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019460_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019462_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019463_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019464_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019466_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019467_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019469_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019470_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019471_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019473_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019474_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019476_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019478_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019479_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019480_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019481_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019482_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019483_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019487_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019488_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019489_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019490_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019491_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019492_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019493_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019495_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019496_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019497_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019498_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019499_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019501_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019502_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019506_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019508_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019509_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019510_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019511_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019512_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019513_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019515_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019516_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019517_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019518_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019519_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019520_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019521_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019523_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019524_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019525_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019526_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019527_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019528_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019530_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019532_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019533_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019535_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019536_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019537_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019538_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019539_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019541_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019542_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019543_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019544_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019546_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019547_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019550_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019553_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019554_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019555_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019556_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019557_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019559_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019560_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019563_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019564_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019565_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019566_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019567_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019568_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019570_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019574_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019575_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019576_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019577_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019578_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019579_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019580_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019582_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019584_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019585_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019586_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019587_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019588_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019589_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019591_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019592_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019593_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train/pose/019595_0_keypoints.json
#   inflating: /content/drive/MyDrive/viton-plus/viton-plus/train_pairs.txt

# %%
class CPDataset:
    def __init__(self, data_path, stage='GMM', fine_height=256, fine_width=192):
        self.data_path = data_path
        self.stage = stage
        self.fine_height = fine_height
        self.fine_width = fine_width

    def data_generator(self, data_list):
        with open(data_list, 'r') as f:
            lines = f.readlines()

        for line in lines:
            im_name, c_name = line.strip().split()
            yield self._parse_function(im_name, c_name)

    def _parse_function(self, im_name, c_name):
        # Load and process the cloth image
        c = tf.io.read_file(os.path.join(self.data_path, 'cloth', c_name))
        c = tf.image.decode_jpeg(c, channels=3)
        cm = tf.io.read_file(os.path.join(self.data_path, 'cloth-mask', c_name))
        cm = tf.image.decode_jpeg(cm, channels=1)

        # Normalize images
        c = tf.cast(c, tf.float32) / 127.5 - 1
        cm = tf.cast(cm >= 128, tf.float32)

        # Load person image
        im = tf.io.read_file(os.path.join(self.data_path, 'image', im_name))
        im = tf.image.decode_jpeg(im, channels=3)
        im = tf.cast(im, tf.float32) / 127.5 - 1

        # Load and process parsing image
        parse_name = im_name.replace('.jpg', '.png')
        im_parse = tf.io.read_file(os.path.join(self.data_path, 'image-parse-new', parse_name))
        im_parse = tf.image.decode_png(im_parse, channels=1)
        parse_array = tf.cast(im_parse, tf.int32)

        # Load and process mask image
        im_mask = tf.io.read_file(os.path.join(self.data_path, 'image-mask', parse_name))
        im_mask = tf.image.decode_png(im_mask, channels=1)
        mask_array = tf.cast(im_mask, tf.int32)

        # Create parse shape
        parse_shape = tf.cast(mask_array > 0, tf.float32)

        # Select parse head for GMM stage
        if self.stage == 'GMM':
            parse_head = tf.cast(
                tf.equal(parse_array, 1) | tf.equal(parse_array, 4) | tf.equal(parse_array, 13), tf.float32)
        else:
            parse_head = tf.cast(
                tf.equal(parse_array, 1) | tf.equal(parse_array, 2) | tf.equal(parse_array, 4) |
                tf.equal(parse_array, 9) | tf.equal(parse_array, 12) | tf.equal(parse_array, 13) |
                tf.equal(parse_array, 16) | tf.equal(parse_array, 17), tf.float32)

        # Select parse cloth
        parse_cloth = tf.cast(
            tf.equal(parse_array, 5) | tf.equal(parse_array, 6) | tf.equal(parse_array, 7), tf.float32)

        # Resize and process shape
        parse_shape = tf.image.resize(parse_shape, (self.fine_height, self.fine_width))
        shape = tf.expand_dims(parse_shape, axis=-1) * 2 - 1

        # Create agnostic representation
        print(f"Shape of im: {im.shape}")

        # Ensure parse_head_expanded has the correct shape (expand dims if necessary)
        if len(parse_head_expanded.shape) == 3:  # Assuming it's missing the channel dimension
            parse_head_expanded = tf.expand_dims(parse_head_expanded, axis=-1)
        print(f"Shape of parse_head_expanded: {parse_head_expanded.shape}")
        parse_head_expanded = parse_head_expanded = tf.broadcast_to(parse_head_expanded, tf.shape(im))
        print(f"Shape of parse_head_expanded: {parse_head_expanded.shape}")

        # Combine head and original image
        im_h = im * parse_head_expanded - (1 - parse_head_expanded)

        return {'image': im_h, 'cloth': c, 'cloth_mask': cm, 'parse_shape': shape, 'parse_cloth': parse_cloth}

# %%
# Create a dataloader using tf.data.Dataset.from_generator
def create_dataloader(dataroot, datamode, stage, data_list, fine_height, fine_width, radius, batch_size, shuffle=False, warp_cloth_available=False):
    dataset_obj = CPDataset(
        data_path=dataroot,
        stage=stage,
        fine_height=fine_height,
        fine_width=fine_width
    )

    dataset = tf.data.Dataset.from_generator(
        lambda: dataset_obj.data_generator(data_list),
        output_signature={
            'image': tf.TensorSpec(shape=(fine_height, fine_width, 3), dtype=tf.float32),
            'cloth': tf.TensorSpec(shape=(fine_height, fine_width, 3), dtype=tf.float32),
            'cloth_mask': tf.TensorSpec(shape=(fine_height, fine_width, 1), dtype=tf.float32),
            'parse_shape': tf.TensorSpec(shape=(fine_height, fine_width, 1), dtype=tf.float32),
            'parse_cloth': tf.TensorSpec(shape=(fine_height, fine_width, 1), dtype=tf.float32)
        }
    )

    if shuffle:
        dataset = dataset.shuffle(buffer_size=1000)  # Adjust buffer size as needed

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

    return dataset

# %%
# Dictionary with options for creating the dataloader
options = {
    'dataroot': '/content/drive/MyDrive/viton-plus/viton-plus/train',
    'datamode': 'train',
    'stage': 'GMM',
    'data_list': '/content/drive/MyDrive/viton-plus/viton-plus/train_pairs.txt',
    'fine_height': 256,
    'fine_width': 256,
    'radius': 10,
    'batch_size': 16,
    'shuffle': True
}

# Create the dataset using the defined options
dataset = create_dataloader(
    dataroot=options['dataroot'],
    datamode=options['datamode'],
    stage=options['stage'],
    data_list=options['data_list'],
    fine_height=options['fine_height'],
    fine_width=options['fine_width'],
    radius=options['radius'],
    batch_size=options['batch_size'],
    shuffle=options['shuffle'],
    warp_cloth_available=False
)

# %%
# Iterate over the dataset and display batch contents
for batch in dataset.take(1):
    print("Batch contents:")
    for key, value in batch.items():
        print(f"{key}: {value.shape}, dtype: {value.dtype}")

    im = batch['image'][0].numpy()
    im = (im + 1) * 127.5  # Convert back to [0, 255] range
    im = im.astype(np.uint8)

    # Display the image
    plt.imshow(im)
    plt.title("Sample Image")
    plt.axis('off')
    plt.show()
# Out:
# Shape of im: (256, 192, 3)
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-38-2c1f212610c4> in <cell line: 2>()
#       1 # Iterate over the dataset and display batch contents
# ----> 2 for batch in dataset.take(1):
#       3     print("Batch contents:")
#       4     for key, value in batch.items():
#       5         print(f"{key}: {value.shape}, dtype: {value.dtype}")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     824   def __next__(self):
#     825     try:
# --> 826       return self._next_internal()
#     827     except errors.OutOfRangeError:
#     828       raise StopIteration
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     774     # to communicate that there is no more data to iterate over.
#     775     with context.execution_mode(context.SYNC):
# --> 776       ret = gen_dataset_ops.iterator_get_next(
#     777           self._iterator_resource,
#     778           output_types=self._flat_output_types,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    3084       return _result
#    3085     except _core._NotOkStatusException as e:
# -> 3086       _ops.raise_from_not_ok_status(e, name)
#    3087     except _core._FallbackException:
#    3088       pass
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    5981 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5982   e.message += (" name: " + str(name if name is not None else ""))
# -> 5983   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    5984
#    5985
#
# UnknownError: {{function_node __wrapped__IteratorGetNext_output_types_5_device_/job:localhost/replica:0/task:0/device:CPU:0}} UnboundLocalError: local variable 'parse_head_expanded' referenced before assignment
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/script_ops.py", line 270, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_generator_op.py", line 198, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "<ipython-input-35-1ca5908582d6>", line 14, in data_generator
#     yield self._parse_function(im_name, c_name)
#
#   File "<ipython-input-35-1ca5908582d6>", line 68, in _parse_function
#     if len(parse_head_expanded.shape) == 3:  # Assuming it's missing the channel dimension
#
# UnboundLocalError: local variable 'parse_head_expanded' referenced before assignment
#
#
# 	 [[{{node PyFunc}}]] [Op:IteratorGetNext] name:
